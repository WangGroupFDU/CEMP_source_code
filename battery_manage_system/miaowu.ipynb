# %%
import numpy as np
import matplotlib.pyplot as plt

prediction_data=np.load("predictions.npy",allow_pickle=True)

# %%
len(prediction_data[0])

# %%
xs,ys=[],[]
for i in prediction_data[0]:
    x,y=i["x"],i["y"]
    xs.append(x)
    ys.append(y)

# %%
fig=plt.figure(figsize=(10,6))
plt.plot(ys,xs)
