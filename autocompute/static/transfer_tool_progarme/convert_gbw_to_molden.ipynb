# %% [markdown]
# # Public pseudocode: convert gbw to molden
#
# - Original workflow path: `autocompute/static/transfer_tool_progarme/convert_gbw_to_molden.ipynb`
# - Workflow family: transfer tool progarme
# - Workflow role: convert calculation files between supported intermediate formats
#
# This public-release notebook preserves the high-level workflow logic while omitting executable implementation details. It is intended to describe the control flow, required inputs, validation points, and expected outputs for third-party review.
#
# ## Pseudocode
#
# 1. Identify the CEMP workflow context for `autocompute/static/transfer_tool_progarme/convert_gbw_to_molden.ipynb`.
# 2. Load only the task metadata, public template inputs, and local paths required for this workflow step.
# 3. Validate required molecular identifiers, structure files, charge records, calculation outputs, and destination folders before processing.
# 4. Execute the high-level workflow role: convert calculation files between supported intermediate formats.
# 5. Apply the same input validation, task-status transitions, and output-recording conventions used by the surrounding CEMP workflow.
# 6. Return a structured status object containing success or failure, generated output paths, warning messages, and record identifiers.
# 7. Stop with an actionable validation error if required inputs, external outputs, or permissions are missing.
#
# ## Logic Consistency Check
#
# - The original notebook contained 4 executable code cells.
# - The public version keeps the same workflow position and input-to-output contract at pseudocode level.
# - The public version intentionally contains no executable code cells.
