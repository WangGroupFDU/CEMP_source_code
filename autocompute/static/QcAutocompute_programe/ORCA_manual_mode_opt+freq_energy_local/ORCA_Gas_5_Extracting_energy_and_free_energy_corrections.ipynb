# %% [markdown]
# # Public pseudocode: ORCA Gas 5 Extracting energy and free energy corrections
#
# - Original workflow path: `autocompute/static/QcAutocompute_programe/ORCA_manual_mode_opt+freq_energy_local/ORCA_Gas_5_Extracting_energy_and_free_energy_corrections.ipynb`
# - Workflow family: QcAutocompute programe
# - Workflow role: extract energies, corrections, and derived descriptors from output files
#
# This public-release notebook preserves the high-level workflow logic while omitting executable implementation details. It is intended to describe the control flow, required inputs, validation points, and expected outputs for third-party review.
#
# ## Pseudocode
#
# 1. Identify the CEMP workflow context for `autocompute/static/QcAutocompute_programe/ORCA_manual_mode_opt+freq_energy_local/ORCA_Gas_5_Extracting_energy_and_free_energy_corrections.ipynb`.
# 2. Load only the task metadata, public template inputs, and local paths required for this workflow step.
# 3. Validate required molecular identifiers, structure files, charge records, calculation outputs, and destination folders before processing.
# 4. Execute the high-level workflow role: extract energies, corrections, and derived descriptors from output files.
# 5. For quantum-chemistry workflows, create engine-specific input descriptions from validated molecules or reactions without embedding private execution settings.
# 6. Monitor calculation states, detect recoverable failures, apply the documented retry decision tree, and record final energies or descriptors.
# 7. Return a structured status object containing success or failure, generated output paths, warning messages, and record identifiers.
# 8. Stop with an actionable validation error if required inputs, external outputs, or permissions are missing.
#
# ## Logic Consistency Check
#
# - The original notebook contained 14 executable code cells.
# - The public version keeps the same workflow position and input-to-output contract at pseudocode level.
# - The public version intentionally contains no executable code cells.
